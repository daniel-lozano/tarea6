# %%
# %pylab inline
import matplotlib.pyplot as plt
import numpy as np
from numpy import pi
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
archivo=np.loadtxt(open("datos_1.dat","r"))
archivo1=np.loadtxt(open("datos_2.dat","r"))

# %% [markdown]
# ## Se tiene los datos iniciales graficados

# %%
#se guardan los datos iniciales
x=archivo[:,1]
y=archivo[:,2]
vx=archivo[:,3]
vy=archivo[:,4]


#orbita 1, prueva de si estan bien 
x1=np.empty(12)
vx1=np.empty(12)
y1=np.empty(12)
vy1=np.empty(12)
#orbita 1 
for i in range (12):
    x1[i]=x[i+1]
    y1[i]=y[i+1]
    vx1[i]=vx[i+1]
    vy1[i]=vy[i+1]

plot(x1,y1,"ro",label="Posiciones")

legend()
xlabel("X")
ylabel("Y")

plt.show()
plt.close()

plot(vx1,label="vx")
plot(vy1,label="vy")
legend()
xlabel("Vx")
ylabel("Vy")
#xlim(-15,15)
#ylim(-15,15)
plt.show()
plt.close()

# %%
plot(x,y,"k*")

# %%
plot(x,y)
title("Puntos")
xlabel("X")
ylabel("Y")
plt.show()
plt.close()
plot(x,y,"ko")
title("Puntos")
xlabel("X")
ylabel("Y")
ylim(-100000,100000)
xlim(-100000,100000)
savefig("galaxias")
plot(x[0],y[0],"ro")
plt.show()
plt.close()
plot(x,y,"r*")
title("Puntos")
xlabel("X")
ylabel("Y")
plot(x[0],y[0],"ko")

# %%
print max(x), max(y)
print min(x), min(y)
# Out:
# 50000.0 50000.0
# -50000.0 -50000.0

# %%
plot(vx,vy)
plt.show()
plt.close()
plot(vx,label="vx")
plot(vy,label="vy")
legend()
plt.show()
plt.close()

# %%
"""
existen saltos en la grafica debido a que se grafica la velocidad con los saltos de orbita incluidos, de ahi que cambie su frecuencia

"""

v=(vx+vy)
plot(v,"ro")
plot(v)
print v[0]
# Out:
# 0.0

# %%
x_=archivo1[:,1]
y_=archivo1[:,2]
vx_=archivo1[:,3]
vy_=archivo1[:,4]


#orbita 1, prueva de si estan bien 
x1_=np.empty(12)
vx1_=np.empty(12)
y1_=np.empty(12)
vy1_=np.empty(12)
#orbita 1 
for i in range (12):
    x1_[i]=x_[i+1]
    y1_[i]=y_[i+1]
    vx1_[i]=vx_[i+1]
    vy1_[i]=vy_[i+1]

plot(x_,y_,"*b",label="galaxia 2")
plot(x,y,"*r",label="galaxia 1")

xlabel("X")
ylabel("Y")
savefig("2galaxias")
legend()
xlim(-70000,200000)
ylim(-70000,300000)
plot(x[0],y[0],"ko")
plot(x_[0],y_[0],"ko")

# %%
archivo=np.loadtxt(open("colision.dat","r"))

# %%
x=archivo[:,0]
y=archivo[:,1]
