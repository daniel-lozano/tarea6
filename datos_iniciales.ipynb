# %%
# %pylab inline
import matplotlib.pyplot as plt
import numpy as np
from numpy import pi
from scipy.fftpack import fft, fftfreq
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
archivo=np.loadtxt(open("datos_iniciales.txt","r"))

# %% [markdown]
# ## Se tiene los datos iniciales graficados

# %%
x=archivo[:,1]
y=archivo[:,2]
vx=archivo[:,3]
vy=archivo[:,4]

# %%
plot(x,y)
title("Puntos")
xlabel("X")
ylabel("Y")
plt.show()
plt.close()
plot(x,y,"ko")
title("Puntos")
xlabel("X")
ylabel("Y")
ylim(-100,100)
xlim(-100,100)
plt.show()
plt.close()
plot(x,y,"go")
title("Puntos")
xlabel("X")
ylabel("Y")

# %%
print max(x), max(y)
# Out:
# 50.0 50.0

# %%
plot(vx,vy)
plt.show()
plt.close()
plot(vx,label="vx")
plot(vy,label="vx")
legend()
plt.show()
plt.close()

# %%
v=vx+vy
plot(v)
print v
# Out:
# [ 0.        1.        0.366026 -0.366025 -1.       -1.366025 -1.366025 -1.
#  -0.366025  0.366025  1.        1.366025  1.366025  0.597673  0.123258
#  -0.366025 -0.811159 -1.158456 -1.366025 -1.408832 -1.281713 -1.       -0.597673
#  -0.123258  0.366025  0.81116   1.158456  1.366025  1.408832  1.281713  1.
#   0.707107  0.366026  0.       -0.366025 -0.707107 -1.       -1.224745
#  -1.366025 -1.414214 -1.366025 -1.224745 -1.       -0.707107 -0.366025  0.
#   0.366025  0.707107  1.        1.224745  1.366025  1.414214  1.366025
#   1.224745  1.        0.770236  0.50681   0.221232 -0.074014 -0.366025
#  -0.642039 -0.889993 -1.09905  -1.260073 -1.366025 -1.412276 -1.396802
#  -1.320282 -1.18606  -1.       -0.770236 -0.506808 -0.221232  0.074014
#   0.366025  0.64204   0.889993  1.09905   1.260074  1.366025  1.412276
#   1.396802  1.320282  1.18606   1.       -0.366025 -0.123258  0.123256
#   0.366025  0.597673  0.81116   1.        1.158456  1.281713  1.366025
#   1.408832  1.408832  1.366025  1.281713  1.158456  1.        0.81116
#   0.597673  0.366025  0.123256 -0.123256 -0.366025 -0.597673 -0.81116  -1.
#  -1.158456 -1.281713 -1.366025 -1.408832 -1.408832 -1.366025 -1.281713
#  -1.158456 -1.       -0.81116  -0.597673]
